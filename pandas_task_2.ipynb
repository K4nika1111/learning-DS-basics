# %% [markdown]
# <a href="https://colab.research.google.com/github/K4nika1111/learning-DS-basics/blob/main/pandas_task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
fruits={'red':'Apple','blue': 'blueberry', 'yellow':'mango','green': 'grapes'}
fruitsser=pd.Series(fruits, index=['red','blue', 'yellow','green'])
print(fruitsser)
# Out:
# red           Apple
# blue      blueberry
# yellow        mango
# green        grapes
# dtype: object
