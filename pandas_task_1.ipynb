# %% [markdown]
# <a href="https://colab.research.google.com/github/K4nika1111/learning-DS-basics/blob/main/pandas_task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
arr=np.array(['India', 'Japan', 'China', 'Korea', '     Singapore'])
ser1=pd.Series(arr,index=[7,77,8,11,88,])
print(ser1)
# Out:
# 7              India
# 77             Japan
# 8              China
# 11             Korea
# 88         Singapore
# dtype: object
