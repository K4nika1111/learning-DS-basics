# %%
! pip install faker
from faker import Faker
fake = Faker()
email = fake.email()
print(email)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 19.9 MB/s eta 0:00:00
# ...
# moranthomas@example.com
