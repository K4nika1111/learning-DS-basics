# %% [markdown]
# <a href="https://colab.research.google.com/github/K4nika1111/learning-DS-basics/blob/main/Dataframe_task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
dit={ 'movie' : [ 'A quiet place' , 'Downtown abbey', 'Toy story', 'Kung fu Panda'], 'Genre': ['Thriller', 'period drama', 'kids', 'kids'], 'Rating' : ['9', '8', '9', '7']}
df=pd.DataFrame(dit, index= ['1', '2','3','4'])
print(df)
# Out:
#             movie         Genre Rating
# 1   A quiet place      Thriller      9
# 2  Downtown abbey  period drama      8
# 3       Toy story          kids      9
# 4   Kung fu Panda          kids      7
