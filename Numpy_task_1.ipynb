# %% [markdown]
# <a href="https://colab.research.google.com/github/K4nika1111/learning-DS-basics/blob/main/Numpy_task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
revenue = [3 , 3,4,5,6,8,11, 15,20,24]
rev=np.array(revenue)
print(rev)
print("size of revenue array is :" + str(rev.size))
print("shape of revenue array is : " + str(rev.shape))
print("data type of revenue array is : " + str(type(rev)))
print("number of dimentions of  revenue array is :" + str(np.ndim(rev)))
# Out:
# [ 3  3  4  5  6  8 11 15 20 24]
# size of revenue array is :10
# shape of revenue array is : (10,)
# data type of revenue array is : <class 'numpy.ndarray'>
# number of dimentions of  revenue array is :1
